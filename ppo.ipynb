# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# 1. Create the CartPole environment
env = gym.make("Pendulum-v1")

# 2. Instantiate the PPO agent
model = PPO(
    policy="MlpPolicy",  # Multi-layer Perceptron policy
    env=env,
    learning_rate=0.0003,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.0,
    verbose=1,
)

# 3. Train the PPO agent
print("Training the PPO agent...")
model.learn(total_timesteps=100000)  # Adjust timesteps as needed

# 4. Save the trained model
model.save("ppo_cartpole")
print("Model saved!")


mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=3)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Training the PPO agent...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -1.2e+03 |
# | time/              |          |
# |    fps             | 442      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 353          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0017904034 |
# |    clip_fraction        | 0.00474      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.00411      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.89e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00101     |
# |    std                  | 0.997        |
# |    value_loss           | 9.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0022616296 |
# |    clip_fraction        | 0.0064       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.1e+03      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00119     |
# |    std                  | 0.995        |
# |    value_loss           | 6.34e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0028750983 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0538       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.61e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 0.985        |
# |    value_loss           | 8.39e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 5            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0015025778 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0227       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.74e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000603    |
# |    std                  | 0.979        |
# |    value_loss           | 8.41e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.19e+03    |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 6            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0034056427 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00998      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.55e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00288     |
# |    std                  | 0.967        |
# |    value_loss           | 7.22e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.17e+03   |
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 7           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.001646084 |
# |    clip_fraction        | 0.00474     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00153     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.48e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000725   |
# |    std                  | 0.962       |
# |    value_loss           | 9.82e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.16e+03   |
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 8           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.002813796 |
# |    clip_fraction        | 0.0179      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00459     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.47e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00178    |
# |    std                  | 0.957       |
# |    value_loss           | 5.71e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.15e+03   |
# | time/                   |             |
# |    fps                  | 320         |
# |    iterations           | 9           |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.003941827 |
# |    clip_fraction        | 0.0264      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00149     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.67e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00164    |
# |    std                  | 0.962       |
# |    value_loss           | 5.71e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -1.15e+03  |
# | time/                   |            |
# |    fps                  | 320        |
# |    iterations           | 10         |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00226164 |
# |    clip_fraction        | 0.00884    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.000814   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.65e+03   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.000367  |
# |    std                  | 0.957      |
# |    value_loss           | 5.54e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 11           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0046034446 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000407     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.32e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00405     |
# |    std                  | 0.95         |
# |    value_loss           | 7.02e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 12           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0027187192 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000459     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.946        |
# |    value_loss           | 5.87e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 13           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0036606574 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.000296     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.95e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00214     |
# |    std                  | 0.929        |
# |    value_loss           | 6.26e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 14           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0038761059 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000313     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.41e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00194     |
# |    std                  | 0.927        |
# |    value_loss           | 5.72e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 15           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0024979562 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000248     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.44e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00193     |
# |    std                  | 0.916        |
# |    value_loss           | 5.08e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 16           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0021127083 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00019      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.55e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00268     |
# |    std                  | 0.923        |
# |    value_loss           | 4.95e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 17           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0037351027 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00014      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.21e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000378    |
# |    std                  | 0.928        |
# |    value_loss           | 4.52e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 18           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0065603293 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00013      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.24e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00343     |
# |    std                  | 0.943        |
# |    value_loss           | 4.69e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.11e+03    |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 19           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0010835534 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 8.4e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.69e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000793    |
# |    std                  | 0.95         |
# |    value_loss           | 4.11e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 20           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0028904967 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 5.7e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.35e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00182     |
# |    std                  | 0.952        |
# |    value_loss           | 4.52e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 21           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0028523356 |
# |    clip_fraction        | 0.0157       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 5.8e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.43e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00141     |
# |    std                  | 0.946        |
# |    value_loss           | 4.75e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -1.1e+03   |
# | time/                   |            |
# |    fps                  | 314        |
# |    iterations           | 22         |
# |    time_elapsed         | 143        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00338385 |
# |    clip_fraction        | 0.0241     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 4.13e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.67e+03   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00184   |
# |    std                  | 0.929      |
# |    value_loss           | 3.75e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.1e+03    |
# | time/                   |             |
# |    fps                  | 315         |
# |    iterations           | 23          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.000756916 |
# |    clip_fraction        | 0.00146     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 3.4e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.39e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000101   |
# |    std                  | 0.921       |
# |    value_loss           | 5.11e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 314         |
# |    iterations           | 24          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004989733 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 3.1e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.94e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00328    |
# |    std                  | 0.915       |
# |    value_loss           | 4.59e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 313          |
# |    iterations           | 25           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0027945277 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 3.03e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.04e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00061     |
# |    std                  | 0.91         |
# |    value_loss           | 3.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 313          |
# |    iterations           | 26           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0041029663 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 2.78e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92e+03     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00295     |
# |    std                  | 0.9          |
# |    value_loss           | 4.07e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 309         |
# |    iterations           | 27          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.003527918 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 2.29e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.7e+03     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00129    |
# |    std                  | 0.9         |
# |    value_loss           | 3.72e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 306          |
# |    iterations           | 28           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0042553386 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 2.17e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.42e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00295     |
# |    std                  | 0.888        |
# |    value_loss           | 3.32e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 29          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004671923 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 1.81e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00143    |
# |    std                  | 0.897       |
# |    value_loss           | 2.71e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 30           |
# |    time_elapsed         | 201          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0022448641 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 1.56e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000404    |
# |    std                  | 0.9          |
# |    value_loss           | 4.09e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 303          |
# |    iterations           | 31           |
# |    time_elapsed         | 208          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0041882363 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 1.48e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.49e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00349     |
# |    std                  | 0.903        |
# |    value_loss           | 2.9e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 303          |
# |    iterations           | 32           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0035353978 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 1.25e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000814    |
# |    std                  | 0.912        |
# |    value_loss           | 2.97e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 302          |
# |    iterations           | 33           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0033522504 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 1e-05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00253     |
# |    std                  | 0.905        |
# |    value_loss           | 2.81e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.06e+03   |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 34          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005201703 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 9.06e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00333    |
# |    std                  | 0.888       |
# |    value_loss           | 2.86e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 35           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0049184193 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 6.97e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.03e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00337     |
# |    std                  | 0.867        |
# |    value_loss           | 2.33e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.08e+03   |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 36          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.002831989 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 7.93e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00216    |
# |    std                  | 0.871       |
# |    value_loss           | 2.93e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 37           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0034900266 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 3.81e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.85e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00225     |
# |    std                  | 0.867        |
# |    value_loss           | 4.19e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.08e+03   |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 38          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.006526414 |
# |    clip_fraction        | 0.0632      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 8.29e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00397    |
# |    std                  | 0.868       |
# |    value_loss           | 2.13e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 39           |
# |    time_elapsed         | 267          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0020140223 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 6.79e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000402    |
# |    std                  | 0.871        |
# |    value_loss           | 2.59e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.08e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 40          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.002036094 |
# |    clip_fraction        | 0.0147      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 7.93e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1e+03       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00111    |
# |    std                  | 0.871       |
# |    value_loss           | 1.91e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.07e+03   |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 41          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004796792 |
# |    clip_fraction        | 0.049       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 7.27e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00489    |
# |    std                  | 0.865       |
# |    value_loss           | 1.99e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 42           |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0024237286 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 4.65e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 882          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0014      |
# |    std                  | 0.847        |
# |    value_loss           | 2.44e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.07e+03   |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 43          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004553872 |
# |    clip_fraction        | 0.0418      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 4.53e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00245    |
# |    std                  | 0.844       |
# |    value_loss           | 2.29e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.05e+03   |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 44          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005009297 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 4.29e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 704         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00286    |
# |    std                  | 0.854       |
# |    value_loss           | 1.55e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.05e+03    |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 45           |
# |    time_elapsed         | 311          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0049255174 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 4.29e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 423          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00385     |
# |    std                  | 0.85         |
# |    value_loss           | 1.37e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.02e+03   |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 46          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004881406 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 3.04e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 607         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00429    |
# |    std                  | 0.831       |
# |    value_loss           | 1.34e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.03e+03    |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 47           |
# |    time_elapsed         | 325          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0043149935 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 2.74e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 555          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00262     |
# |    std                  | 0.815        |
# |    value_loss           | 1.29e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.03e+03    |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 48           |
# |    time_elapsed         | 333          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0044675255 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 3.16e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 561          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00299     |
# |    std                  | 0.805        |
# |    value_loss           | 1.59e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.03e+03    |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 49           |
# |    time_elapsed         | 340          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0026735077 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 2.62e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 560          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000786    |
# |    std                  | 0.799        |
# |    value_loss           | 1.71e+03     |
# ------------------------------------------
# Model saved!
# Mean reward: -976.32 +/- 101.32

# %%
env = gym.make("Pendulum-v1", render_mode = 'human')
# 5. Load the trained model (optional)
model = PPO.load("ppo_cartpole", env=env)

# 6. Evaluate the trained policy

# 7. Run the trained agent
obs, _ = env.reset()
for i in range(1000):  # Run for a fixed number of timesteps
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, _ = env.step(action)
    env.render()
    if terminated or truncated:
        obs, _ = env.reset()
        print("Done ", i)
    # if not i%20: print(i)

env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Done  199
# Done  399
# Done  599
# Done  799
# Done  999
